# %% [markdown]
# <a href="https://colab.research.google.com/github/FedericoRaschiatore0123/Neural_Network/blob/main/Adversarial_Diffusion_Distillation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Method Description

# %% [markdown]
# The Adversarial Diffusion Distillation (ADD) is a novel approach that aims to efficently samples images in just a few steps.The idea is combine the power of Adversarial networks and the distillation technique in order to synthetize high quality images in a small number of iterations.
#
# In the original paper Sauer et. al. the idea was to synthetize the images in 1-4 steps using pretrained models. Their analysis show that the models outperform the results of existing models and reach the performances of the State of the art (SDXL) in only 4 steps.
#
# The original model is composed by 3 parts:
#
#
# *   **ADD-student**: is a pretrained diffusion model that aims to synthetize the images in a few steps (1-4) starting from a noised version of the original image. So this model can use only from 1 to 4 iterations to denoise the input image. The parameters of this model are trainable.
# *   **DM-teacher**: is also a pretrained diffusion model but differently from the student, it can use a larger number of iterations to denoise the input. It has fixed parameters.
# *   **ViT Discriminator**: is a pretrained Vision Transformer that they adapt to use as a discriminator with trainable parameters.
#
# The key idea for the training procedure is:
#
# 1.   Take a Real image
# 2.   Introduce some noise
# 3.   Pass the noised version of the original image through the ADD-student
# 4.   Pass the output of ADD-student through the discriminator and compute the Adversarial Loss
# 5.   Introduce some other noise to the resulting image from the ADD-student
# 6.   Pass it through the DM-teacher and compute the distillation loss using the outputs from the ADD-student and DM-teacher
# 7.   Compute the total loss summing up the two losses and backpropagate it to the ADD-student and to the discriminator
#
# The two losses that have been computed are the Adversarial Loss and the Distillation Loss that are defined as follows:
#
# Adversarial loss that is the loss of the adversarial process and is used to update the weights of the discriminator:
#
#
# $$L_{adv}^G(\hat{x}_{\theta}(x_s, s), \phi) = -\mathbb{E}_{s,\epsilon,x_0} \left[ \sum_{k} D_{\phi,k} \left( F_k(\hat{x}_{\theta}(x_s, s)) \right) \right] $$
#
# $$L_{adv}^D(\hat{x}_{\theta}(x_s, s), \phi) = \mathbb{E}_{x_0} \left[ \sum_{k} \max(0, 1 - D_{\phi,k}(F_k(x_0))) + \gamma R_1(\phi) \right] + \mathbb{E}_{\hat{x}_{\theta}} \left[ \sum_{k} \max(0, 1 + D_{\phi,k}(F_k(\hat{x}_{\theta}))) \right]
# $$
#
#
# Distillation loss:
#
# $$L_{\text{distill}}(\hat{x}_{\theta}(x_s, s), \psi) = \mathbb{E}_{t,\epsilon'} \left[ c(t) \cdot d(\hat{x}_{\theta}, \hat{x}_{\psi}(s, g(\hat{x}_{\theta}, t); t)) \right]$$
#
#
#
# The total loss is:
#
# $$L_{total} = L_{adv}^D(\hat{x}_{\theta}(x_s, s), \phi) + L_{\text{distill}}(\hat{x}_{\theta}(x_s, s), \psi)$$
#
#
#
# To avoid the use of pretrained model i implemented a Denoise diffusion model and a Discriminator model based on a ViT architecture as can be seen below.
#
# I tested the model for 2 different datasets:
#
# * MNIST is a dataset containing images of hand written numbers. I tested the model using a fixed image size of 32x32
#
# * FER2013 is a dataset containing human faces that express different emotions. I have tried to work in using 3 channels but the model became too heavy and the training too slow so I decided to use only 1 channel in order to obtain good results in a relatively small time
#
# To each dataset is associated a set of global variables, if you want to switch between the two dataset you have to select the dataset in the second cell.

# %% [markdown]
# <center>
#
# ![Baseline](https://miro.medium.com/v2/resize:fit:1400/0*cWVcA2VMGByT10qP.jpg)
#
# </center>

# %% [markdown]
# ORIGINAL PAPER:
#  https://static1.squarespace.com/static/6213c340453c3f502425776e/t/65663480a92fba51d0e1023f/1701197769659/adversarial_diffusion_distillation.pdf
#
# DIFFUSION MODEL:
#  https://arxiv.org/pdf/2006.11239.pdf
#
# DIFFUSION MODEL CODE:
# https://colab.research.google.com/drive/1sjy9odlSSy0RBVgMTgP7s99NXsqglsUL?usp=sharing#scrollTo=BIc33L9-uK4q (used this as reference)
#
# VISION TRANSFORMER:
#  https://arxiv.org/pdf/2010.11929

# %% [markdown]
# # Globals
# This global variables represent the configuration used for the training of the variious section of the project. They are splitted in two different sections depending on the dataset that you decide to use.
#
# 1. **General Variables:**
#    - `batch size` : determine the number of elements for each batch
#    - `channels` : determine the number of channels of the input image
#    - `image_size` : determine the chosen dimension for the input images
#    - `dataset` : the name of the chosen dataset
#
# 2. **Diffusion Model Training:**
#    - `epochs` : the selected number of epochs for the training process
#    - `timesteps` : the number of the chosen timestep for the forward process
#   - `lr` : the starting learning rate value
#   - `patience` : the number of patience epochs used for the scheduler
#   - `factor` : the decreasing factor for the scheduler
#   - `beta_start` : the starting value for the
#   - `beta_end` : 0.02,
#   - `dim_mults` : the dimensions used for the downsampling and upsampling process
#   - `with_time_emb` : a boolean value used to determine whether time embedding is used or not
#   - `resnet_block_groups` : number of resnet blocks used
#   - `convnext_mult` :
#
# 3. **ViT Discriminator:**
#    - `embed_dim`: the chosen embed size for the model.
#    - `hidden_dim` : the chosen hidden dimension for the transformer
#    - `out_dim` : the output dimension (binary decision)
#   - `patch_size` : the dimension of the patch for the transformer
#   - `n_layers` : the number of layers for the transofmer
#   - `dropout` : the dropout value
#   - `num_heads` : the selected number of heads
#   - `vit_epochs` : the selected numbe rof epochs for the training process
#   - `vit_lr` : : the starting learning rate value
#   - `patience` : the number of patience epochs used for the scheduler
#   - `factor` :  the decreasing factor for the scheduler
#
# 4. **Adversarial Diffusion Distillation:**
#    - `student_path`: specifies the path for the pretrained weights of the student model
#    - `teacher_path`: specifies the path for the pretrained weights of the teacher model
#    - `discriminator_path`: specifies the path for the pretrained weights of the discriminator model
#    - `student_timesteps`: specifies the number of timesteps used for the student denoising process
#    - `teacher_timesteps`: specifies the number of timesteps used for the teacher denoising process
#    - `lambda`: specifies the increasing factor of the distillation loss
#    - `regularization_term`: specifies the regularization term factor
#    - `number_of_steps`: number of steps used to reduce the number of training batches
#
# 5. **Pretrain phase:**
#   - `pretrain_epochs`: the selected number of epochs for the pretrain process
#   - `pretrain_lr`: the starting learning rate value
#   - `pretrain_patience`: the number of patience epochs used for the scheduler
#   - `pretrain_scheduler_factor`: the decreasing factor for the scheduler
#
# 6. **ADD training phase:**
#    - `add_train_epochs`: the selected number of epochs for the pretrain process
#   - `student_lr`: the starting learning rate value
#   - `discriminator_lr`: the starting learning rate value
#   - `add_patience`: the number of patience epochs used for the scheduler
#   - `add_factor`: the decreasing factor for the scheduler
#
# These variables are designed to provide a flexible, modular and centralized configuration of aspects relevant to the project.
#
# I provided two different sets of parameter depending on the chosen dataset. You can choose the dataset from the cell above.

# %%
global_var_mnist = {

    #general variables
    "batch_size" : 64,
    "channels" : 1,
    "image_size" : 32,
    "dataset" : "MNIST",
    "fine_tune" : False,

    #diffusion model
    "epochs":25,
    "timesteps": 500,
    "lr" : 1e-3,
    "patience" : 7,
    "factor" : 0.1,
    "beta_start" : 0.0001,
    "beta_end" : 0.02,
    "dim_mults" : (1, 2, 4, 8),
    "with_time_emb" : True,
    "resnet_block_groups" : 4,
    "convnext_mult" : 2,

    #ViT discriminator
    "embed_dim" : 32,
    "hidden_dim" : 512,
    "out_dim" : 1,
    "patch_size" : 8,
    "n_layers" : 3,
    "img_size" : 32,
    "dropout" : 0.1,
    "num_heads" : 4,
    "vit_epochs" : 5,
    "vit_lr" : 1e-3,
    "patience" : 2,
    "factor" : 0.1,

    #ADD
    "student_path" : "/content/Neural_Network/models/student_model_mnist1.pth",
    "teacher_path" : "/content/Neural_Network/models/diffusion_model_mnist.pth",
    "discriminator_path" : "/content/Neural_Network/models/discriminator_model_mnist.pth",
    "student_timesteps" : 4,
    "teacher_timesteps" : 500,
    "lambda" : 2.5,
    "regularization_term" : 2,
    "number_of_steps" : 50,

    #pretrain
    "pretrain_epochs" : 10,
    "pretrain_lr" : 1e-3,
    "pretrain_patience" : 5,
    "pretrain_scheduler_factor" : 0.1,

    #ADD train
    "add_train_epochs" : 50,
    "student_lr" : 1e-3,
    "discriminator_lr" : 1e-3,
    "add_patience" : 15,
    "add_factor" : 0.1,

}

global_var_fer = {

    #general variables
    "batch_size" : 64,
    "channels" : 1,
    "image_size" : 32,
    "dataset" : "FER",
    "fine_tune" :False,

    #diffusion model
    "epochs":40,
    "timesteps" : 500,
    "lr" : 1e-4,
    "patience" : 10,
    "factor" : 0.1,
    "lr_ft" : 1e-4,
    "beta_start" : 0.0001,
    "beta_end" : 0.02,
    "dim_mults" : (1, 2, 4, 8),
    "with_time_emb" : True,
    "resnet_block_groups" : 4,
    "convnext_mult" : 2,

    #ViT discriminator
    "embed_dim" : 32,
    "hidden_dim" : 512,
    "out_dim" : 1,
    "patch_size" : 8,
    "n_layers" : 3,
    "img_size" : 32,
    "dropout" : 0.1,
    "num_heads" : 4,
    "vit_epochs" : 5,
    "vit_lr" : 1e-3,
    "patience" : 2,
    "factor" : 0.1,

    #ADD
    "student_path" : "/content/Neural_Network/models/student_model_fer_1.pth",
    "teacher_path" : "/content/Neural_Network/models/diffusion_model_fer_1.pth",
    "discriminator_path" : "/content/Neural_Network/models/discriminator_model_fer_1.pth",
    "student_timesteps" : 4,
    "teacher_timesteps" : 500,
    "lambda" : 2.5,
    "regularization_term" : 2,
    "number_of_steps" : 50,

    #pretrain
    "pretrain_epochs" : 3,
    "pretrain_lr" : 3e-4,
    "pretrain_patience" : 5,
    "pretrain_scheduler_factor" : 0.1,

    #ADD train
    "add_train_epochs" : 50,
    "student_lr" : 3e-4,
    "discriminator_lr" : 1e-4,
    "add_patience" : 15,
    "add_factor" : 0.1,
}

# %%
#@title Select the Dataset { run: "auto" }

model_name = "MNIST" # @param ["FER", "MNIST"]

if model_name == "FER":
  global_var = global_var_fer
elif model_name == "MNIST":
  global_var = global_var_mnist
else:
  print("The inserted name is not valid")

# %% [markdown]
# # Import the pretrained models
#
# Here you can download the pretrained models for the ADD-student, DM-teacher and ViT discriminator from the github and use them to test the results.

# %%
# !rm -r Neural_Network
# !git clone https://github.com/FedericoRaschiatore0123/Neural_Network.git
# Out:
# rm: cannot remove 'Neural_Network': No such file or directory
# Cloning into 'Neural_Network'...
# remote: Enumerating objects: 565, done.
# remote: Counting objects: 100% (153/153), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 565 (delta 88), reused 146 (delta 82), pack-reused 412 (from 1)
# Receiving objects: 100% (565/565), 1.69 GiB | 16.43 MiB/s, done.
# Resolving deltas: 100% (348/348), done.
# Updating files: 100% (16/16), done.

# %% [markdown]
# #Imports
# the project has been built using the following libraries, in particular pytorch and torchvision. In addition i decided to use libraries as numpy and einops to do some particular operations, the torcheval libraries for the evaluations and other libraries to visualize the results as matplotlib.

# %%
# !pip install -q -U einops datasets matplotlib tqdm
# !pip install pytorch-fid
# !pip install torcheval

import math
import torch as torch
from inspect import isfunction
from functools import partial

# %matplotlib inline
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from einops import rearrange
from torch import einsum
import torch.nn.functional as F
import torchvision
import torchvision.transforms as tt
import os
import torch.nn as nn
import numpy as np
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision.utils import make_grid , save_image
import random
from torchvision import datasets
from torch.optim import Adam
from pathlib import Path
from pytorch_fid.inception import InceptionV3
from torchvision.transforms.functional import to_pil_image, to_tensor
from einops.layers.torch import Rearrange
from torch import Tensor
from einops import repeat

from scipy.linalg import sqrtm
from torchvision.transforms import ToPILImage
from torchvision import models, transforms
from torcheval import metrics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.6 MB/s eta 0:00:00
# Collecting pytorch-fid
#   Downloading pytorch_fid-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (10.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (1.13.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (2.4.1+cu121)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-fid) (0.19.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1->pytorch-fid) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.1->pytorch-fid) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.1->pytorch-fid) (1.3.0)
# Downloading pytorch_fid-0.3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pytorch-fid
# Successfully installed pytorch-fid-0.3.0
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torcheval) (4.12.2)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7

# %% [markdown]
# #Get Device

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device('cpu')

# %% [markdown]
# #Dataset and transformations
# In this section it's imported the dataset and are applied the following transformations depending on the dataset.

# %%
if global_var["dataset"] == "FER":

  # !rm -r train
  # !rm -r Vision_and_Perception
  # !git clone https://github.com/FedericoRaschiatore0123/Vision_and_Perception

  # !unzip /content/Vision_and_Perception/Train_1.zip -d train
  # !unzip /content/Vision_and_Perception/Train_2.zip -d train
  # !unzip /content/Vision_and_Perception/Train_3.zip -d train

  train_path = "/content/train"

  transformation = tt.Compose([ tt.Resize((global_var["image_size"])),
                                tt.ToTensor(),
                                tt.Grayscale(),
                          ])

  dataset = datasets.ImageFolder(root=train_path, transform=transformation)

  dataloader = DataLoader(dataset, batch_size=global_var["batch_size"], shuffle=True)

elif global_var["dataset"] == "MNIST":

  transform = tt.Compose([
            tt.Resize(32),
            tt.RandomHorizontalFlip(),
            tt.ToTensor(),
            tt.Lambda(lambda t: (t * 2) - 1),
              ])

  dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)

  dataloader = DataLoader(dataset, batch_size=global_var["batch_size"], shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:04<00:00, 1989533.21it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 345666.44it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 3165954.47it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 782651.85it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
def show_batch(images):
    fig, ax = plt.subplots(figsize=(24, 24))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(images[:32], nrow=8).permute(1, 2, 0))

# %%
show_batch(next(iter(dataloader))[0])
print(next(iter(dataloader))[0].shape)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([64, 1, 32, 32])

# %% [markdown]
# #Forward process
# In this section is sets up the foundational elements for a diffusion model, including the calculation of key parameters based on a linear schedule of noise levels (betas) and the implementation of the forward diffusion process, where an input data point is progressively noised according to the diffusion schedule.

# %%
def linear_beta_schedule(timesteps, beta_start, beta_end):
    return torch.linspace(beta_start, beta_end, timesteps)

def extract(a, t, x_shape):
    batch_size = t.shape[0]
    out = a.gather(-1, t.cpu())
    return out.reshape(batch_size, *((1,) * (len(x_shape) - 1))).to(t.device)

timesteps = global_var['timesteps']

betas = linear_beta_schedule(timesteps, global_var["beta_start"], global_var["beta_end"])

alphas = 1. -  betas
alphas_cumprod = torch.cumprod(alphas, axis=0)
alphas_cumprod_prev = F.pad(alphas_cumprod[:-1], (1, 0), value=1.0)
sqrt_recip_alphas = torch.sqrt(1.0 / alphas)

sqrt_alphas_cumprod = torch.sqrt(alphas_cumprod)
sqrt_one_minus_alphas_cumprod = torch.sqrt(1. - alphas_cumprod)

posterior_variance = betas * (1. - alphas_cumprod_prev) / (1. - alphas_cumprod)

# %%
def q_sample(x_start, t, noise=None):
    if noise is None:
        noise = torch.randn_like(x_start)

    sqrt_alphas_cumprod_t = extract(sqrt_alphas_cumprod, t, x_start.shape)
    sqrt_one_minus_alphas_cumprod_t = extract(
        sqrt_one_minus_alphas_cumprod, t, x_start.shape
    )
    return sqrt_alphas_cumprod_t * x_start + sqrt_one_minus_alphas_cumprod_t * noise, noise

# %%
def show_tensor_image(image):
    reverse_transforms = tt.Compose([
        tt.Lambda(lambda t: (t + 1) / 2),
        tt.Lambda(lambda t: t.permute(1, 2, 0)), # CHW to HWC
        tt.Lambda(lambda t: t * 255.),
        tt.Lambda(lambda t: t.numpy().astype(np.uint8)),
        tt.ToPILImage(),
    ])

    # Take first image of batch
    if len(image.shape) == 4:
        image = image[0, :, :, :]
    plt.imshow(reverse_transforms(image))

# %% [markdown]
# Here you can see a simulation of the forward process that progressively introduce noise inn the original image

# %%
image = next(iter(dataloader))[0]
print(image.shape)

plt.figure(figsize=(15,15))
plt.axis('off')
num_images = 10
stepsize = int(timesteps/num_images)

for idx in range(1, timesteps, stepsize):
    t = torch.Tensor([idx]).type(torch.int64)
    plt.subplot(1, num_images+1, int(idx/stepsize) + 1)
    img, noise = q_sample(image, t)
    show_tensor_image(img)
# Out:
# torch.Size([64, 1, 32, 32])
# <ipython-input-12-df56e04d72ff>:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, num_images+1, int(idx/stepsize) + 1)

# %% [markdown]
# # Diffusion Model
#
# In this section is implemented the diffusion model and all its components. The aim of the diffusion model is learn how to denoise the images that have been noised in the precedent forward pass. In particular this model have to predict the noise that have been inserted in in the original image.
# The architecture is based on a UNet model that pass the image through some residual block of convolutional layers, than downsample and repeat until we reach the desired resolution. After that the image is upsampled and pass through other convolutional layers until reach the original resolution.
#
# In this prcess it's extracted the estimated noise that is compared to the real noise and with this two values we compute the loss that will be backpropagated.
#
# The architecture is based on the paper Denoising diffusion probabilistic model ( https://arxiv.org/pdf/2006.11239.pdf )
#
# <p align="center">
#     <img src="https://nn.labml.ai/unet/unet.png" width="600" />
# </p>

# %% [markdown]
# ##UNeT

# %% [markdown]
# In this section are implemented some function that are useful for all the process. Are also implemented the class Residual that implement the residual connection mechanism and the Prenorm function that is used to normalize the datas

# %%
def exists(x):
    """
    Args:
    x: Any type. The value to check for existence.

    Returns:
    bool: True if x is not None, False otherwise.
    """
    return x is not None

def default(val, d):
    """
    Return a default value if the given value does not exist (is None).

    Args:
    val: Any type. The value to check.
    d: Any type or callable. The default value or a function returning the default value.

    Returns:
    Any type: val if it exists, otherwise d() if d is callable, else d.
    """
    if exists(val):
        return val
    return d() if isfunction(d) else d

class Residual(nn.Module):
    """
    A residual module that adds the input to the output of the given function.

    Args:
    fn: nn.Module. The function to apply to the input.

    Returns:
    The output of fn(x) + x, where x is the input tensor.
    """
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, *args, **kwargs):
        return self.fn(x, *args, **kwargs) + x

def Upsample(dim):
    """
    Create an upsampling layer using ConvTranspose2d.

    Args:
    dim: int. The number of input and output channels.

    Returns:
    nn.ConvTranspose2d: An upsampling layer with a 4x4 kernel, stride of 2, and padding of 1.
    """
    return nn.ConvTranspose2d(dim, dim, 4, 2, 1)

def Downsample(dim):
    """
    Create a downsampling layer using Conv2d.

    Args:
    dim: int. The number of input and output channels.

    Returns:
    nn.Conv2d: A downsampling layer with a 4x4 kernel, stride of 2, and padding of 1.
    """
    return nn.Conv2d(dim, dim, 4, 2, 1)

class PreNorm(nn.Module):
    """
    Apply Group Normalization before the given function.

    Args:
    dim: int. The number of input channels.
    fn: nn.Module. The function to apply after normalization.

    Returns:
    The output of fn(norm(x)), where x is the input tensor and norm is GroupNorm.
    """
    def __init__(self, dim, fn):
        super().__init__()
        self.fn = fn
        self.norm = nn.GroupNorm(1, dim)

    def forward(self, x):
        x = self.norm(x)
        return self.fn(x)

# %% [markdown]
# The noise level is sampled randomly in a range \[ 0, timestep \], so to give information to the model about the level of noise in which it is operating we give an embedding to that specific value using this class that using sine and cosine give an embedding value.

# %%
class SinusoidalPositionEmbeddings(nn.Module):
    """
    Create sinusoidal position embeddings for time steps.

    Args:
    dim: int. The dimensionality of the embeddings.

    Returns:
    torch.Tensor: A tensor of sinusoidal position embeddings for the given time steps.
    """
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = math.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings

# %% [markdown]
# In this section we define the convolution block and the residual convolution block.
# The UnetBlock is the key block of the architecture, is composed by a convolutional layer, a gruop normalization block that normalize the datas and a Sigmoid Linear Unit as activation function.
#
#
# The ResNet represent each layer of the UNet model that we have seen above:
#
# *   We have a first convolutiona block
# *   We concatenate the results of the Sinusoidal Positional Embedding to the output of the first block
# *   We pass the result h through another convolutional layer
# *   We sum up the original input x to the output in order to form a residual connection

# %%
class UNet_Block(nn.Module):
    """
    A basic block for the U-Net model with convolution, normalization, and activation.

    Args:
    dim_input: int. The number of input channels.
    dim_output: int. The number of output channels.
    groups: int. The number of groups for GroupNorm. Default is 4.

    Returns:
    The output tensor after applying convolution, normalization, and activation.
    """
    def __init__(self, dim_input, dim_output, groups=4):
        super().__init__()
        self.proj = nn.Conv2d(dim_input, dim_output, 3, padding=1)
        self.normalization = nn.GroupNorm(groups, dim_output)
        self.act = nn.SiLU()

    def forward(self, x):
        x = self.proj(x)
        x = self.normalization(x)
        x = self.act(x)
        return x


class UNet_ResNet(nn.Module):
    """
      A U-Net block with residual connections and optional time embeddings.

      Args:
      dim: int. The number of input channels.
      dim_out: int. The number of output channels.
      time_emb_dim: int, optional. The dimensionality of the time embeddings. Default is None.
      groups: int. The number of groups for GroupNorm. Default is 4.

      Returns:
      The output tensor after applying the block with residual connections and time embeddings.
    """
    def __init__(self, dim, dim_out, *, time_emb_dim=None, groups=4):
        super().__init__()
        self.mlp = (
            nn.Sequential(nn.SiLU(), nn.Linear(time_emb_dim, dim_out))
            if exists(time_emb_dim)
            else None
        )

        self.block1 = UNet_Block(dim, dim_out, groups=groups)
        self.block2 = UNet_Block(dim_out, dim_out, groups=groups)
        self.res_conv = nn.Conv2d(dim, dim_out, 1) if dim != dim_out else nn.Identity()

    def forward(self, x, time_emb=None):
        h = self.block1(x)

        if exists(self.mlp) and exists(time_emb):
            time_emb = self.mlp(time_emb)
            h = rearrange(time_emb, "b c -> b c 1 1") + h

        h = self.block2(h)
        return h + self.res_conv(x)

# %% [markdown]
# The authors also intorduced some multi-head attention layers between the various convolutional layer,that are implemented as follows.
# The Attention layer is used in the middle part of the UNet instead the LinearAttention is used after each downsample or upsample layer.

# %%
class Attention(nn.Module):
    """
    Multi-head self-attention mechanism.

    Args:
    dim: int. The number of input channels.
    num_heads: int. The number of attention heads. Default is 4.
    dim_head: int. The dimensionality of each head. Default is 32.

    Returns:
    The output tensor after applying the multi-head self-attention mechanism.
    """
    def __init__(self, dim, num_heads=4, dim_head=32):
        super().__init__()
        self.scale = dim_head**-0.5
        self.num_heads = num_heads
        hidden_dim = dim_head * num_heads
        self.to_qkv = nn.Conv2d(dim, hidden_dim * 3, 1, bias=False)
        self.to_out = nn.Conv2d(hidden_dim, dim, 1)

    def forward(self, x):
        b, c, h, w = x.shape
        qkv = self.to_qkv(x).chunk(3, dim=1)
        q, k, v = map(
            lambda t: rearrange(t, "b (h c) x y -> b h c (x y)", h=self.num_heads), qkv
        )
        q = q * self.scale

        sim = einsum("b h d i, b h d j -> b h i j", q, k)
        sim = sim - sim.amax(dim=-1, keepdim=True).detach()
        attn = sim.softmax(dim=-1)

        out = einsum("b h i j, b h d j -> b h i d", attn, v)
        out = rearrange(out, "b h (x y) d -> b (h d) x y", x=h, y=w)
        return self.to_out(out)


class LinearAttention(nn.Module):
    """
    Linear attention mechanism for efficiency.

    Args:
    dim: int. The number of input channels.
    num_heads: int. The number of attention heads. Default is 4.
    dim_head: int. The dimensionality of each head. Default is 32.

    Returns:
    The output tensor after applying the linear attention mechanism.
    """
    def __init__(self, dim, num_heads=4, dim_head=32):
        super().__init__()
        self.scale = dim_head**-0.5
        self.heads = num_heads
        hidden_dim = dim_head * num_heads
        self.to_qkv = nn.Conv2d(dim, hidden_dim * 3, 1, bias=False)

        self.to_out = nn.Sequential(nn.Conv2d(hidden_dim, dim, 1),
                                    nn.GroupNorm(1, dim))

    def forward(self, x):
        b, c, h, w = x.shape
        qkv = self.to_qkv(x).chunk(3, dim=1)
        q, k, v = map(
            lambda t: rearrange(t, "b (h c) x y -> b h c (x y)", h=self.heads), qkv
        )

        q = q.softmax(dim=-2)
        k = k.softmax(dim=-1)

        q = q * self.scale
        context = torch.einsum("b h d n, b h e n -> b h d e", k, v)

        out = torch.einsum("b h d e, b h d n -> b h e n", context, q)
        out = rearrange(out, "b h c (x y) -> b (h c) x y", h=self.heads, x=h, y=w)
        return self.to_out(out)

# %% [markdown]
# Finally we can define the complete UNet. This take in input the batch of noised images and the noise level t and have to predict the noise in the batch.
# What we do is define a sequence of layers each one composed by a UNet_Resnet block, a Linear Attention block and a downsampling/upsampling layer.

# %%
class Unet(nn.Module):
    """
    Define the full UNet model for downsampling and upsampling the image.

    Args:
    dim: int. The base dimensionality for the model.
    init_dim: int, optional. Initial dimensionality of the first convolution layer. If None, defaults to (dim // 3 * 2).
    out_dim: int, optional. Output dimensionality of the final convolution layer. If None, defaults to the number of input channels.
    dim_mults: tuple. Multipliers for the dimensionality of each layer.
    channels: int. The number of input image channels.
    with_time_emb: bool. Whether to include time embeddings.
    resnet_block_groups: int. Number of groups for the GroupNorm in ResNet blocks.
    convnext_mult: int. Multiplicative factor for ConvNeXt layers.

    Inputs:
    x: Tensor. Input image tensor of shape (batch_size, channels, height, width).
    time: Tensor. Time step tensor of shape (batch_size,).

    Outputs:
    Tensor of shape (batch_size, out_dim, height, width). The processed image tensor after applying the UNet.
    """
    def __init__( self, dim, init_dim=None, out_dim=None, dim_mults=(1, 2, 4, 8), channels=1, with_time_emb=True, resnet_block_groups=4, convnext_mult=2):
        super().__init__()

        self.channels = channels

        init_dim = default(init_dim, dim // 3 * 2)
        self.init_conv = nn.Conv2d(channels, init_dim, 7, padding=3)

        dims = [init_dim, *map(lambda m: dim * m, dim_mults)]
        in_out = list(zip(dims[:-1], dims[1:]))

        block_klass = partial(UNet_ResNet, groups=resnet_block_groups)

        # time embeddings
        if with_time_emb:
            time_dim = dim * 4
            self.time_mlp = nn.Sequential(
                SinusoidalPositionEmbeddings(dim),
                nn.Linear(dim, time_dim),

                nn.GELU(),
                nn.Linear(time_dim, time_dim),
            )
        else:
            time_dim = None
            self.time_mlp = None

        # layers
        self.downs = nn.ModuleList([])
        self.ups = nn.ModuleList([])
        num_resolutions = len(in_out)

        for ind, (dim_in, dim_out) in enumerate(in_out):
            is_last = ind >= (num_resolutions - 1)

            self.downs.append(
                nn.ModuleList(
                    [
                        block_klass(dim_in, dim_out, time_emb_dim=time_dim),
                        block_klass(dim_out, dim_out, time_emb_dim=time_dim),
                        Residual(PreNorm(dim_out, LinearAttention(dim_out))),
                        Downsample(dim_out) if not is_last else nn.Identity(),
                    ]
                )
            )

        mid_dim = dims[-1]
        self.mid_block1 = block_klass(mid_dim, mid_dim, time_emb_dim=time_dim)
        self.mid_attn = Residual(PreNorm(mid_dim, Attention(mid_dim)))
        self.mid_block2 = block_klass(mid_dim, mid_dim, time_emb_dim=time_dim)

        for ind, (dim_in, dim_out) in enumerate(reversed(in_out[1:])):
            is_last = ind >= (num_resolutions - 1)

            self.ups.append(
                nn.ModuleList(
                    [
                        block_klass(dim_out * 2, dim_in, time_emb_dim=time_dim),
                        block_klass(dim_in, dim_in, time_emb_dim=time_dim),
                        Residual(PreNorm(dim_in, LinearAttention(dim_in))),
                        Upsample(dim_in) if not is_last else nn.Identity(),
                    ]
                )
            )

        out_dim = default(out_dim, channels)
        self.final_conv = nn.Sequential(
            block_klass(dim, dim), nn.Conv2d(dim, out_dim, 1)
        )


    def forward(self, x, time):
        x = self.init_conv(x)

        t = self.time_mlp(time) if exists(self.time_mlp) else None

        h = []

        # downsample
        for block1, block2, attn, downsample in self.downs:
            x = block1(x, t)
            x = block2(x, t)

            x = attn(x)
            h.append(x)
            x = downsample(x)

        # bottleneck
        x = self.mid_block1(x, t)
        x = self.mid_attn(x)
        x = self.mid_block2(x, t)

        # upsample
        for block1, block2, attn, upsample in self.ups:
            x = torch.cat((x, h.pop()), dim=1)
            x = block1(x, t)
            x = block2(x, t)
            x = attn(x)
            x = upsample(x)
        return self.final_conv(x)

# %%
def p_sample(model, x, t, t_index):
    """
    Sample from the model at a specific timestep using the DDPM sampling algorithm.

    Args:
    model: the diffusion model
    x: Tensor. The input tensor at the current timestep.
    t: Tensor. The current timestep tensor.
    t_index: int. The current index of the timestep in the reverse loop.

    Returns:
    Tensor. The sampled tensor for the next timestep.
    """
    betas_t = extract(betas, t, x.shape)
    sqrt_one_minus_alphas_cumprod_t = extract(
        sqrt_one_minus_alphas_cumprod, t, x.shape
    )
    sqrt_recip_alphas_t = extract(sqrt_recip_alphas, t, x.shape)

    model_mean = sqrt_recip_alphas_t * (
        x - betas_t * model(x, t) / sqrt_one_minus_alphas_cumprod_t
    )

    if t_index == 0:
        return model_mean
    else:
        posterior_variance_t = extract(posterior_variance, t, x.shape)
        noise = torch.randn_like(x)
        return model_mean + torch.sqrt(posterior_variance_t) * noise


def p_sample_loop(model, img, shape, timesteps):
    """
    Generate a sequence of samples from the model by iterating through timesteps in reverse order.

    Args:
    model: the diffusion model
    img: Tensor. The initial input tensor.
    shape: tuple. The shape of the output tensor (batch_size, channels, height, width).
    timesteps: int. The total number of timesteps to iterate through.

    Returns:
    List[Tensor]. A list of sampled tensors at each timestep.
    """
    device = next(model.parameters()).device

    b = shape[0]
    imgs = []

    for i in reversed(range(0, timesteps)):
        img = p_sample(model, img, torch.full((b,), i, device=device, dtype=torch.long), i)
        imgs.append(img)
    return imgs


def sample(model, img, image_size, timestep, batch_size=64, channels=1):
    """
    Generate a full sequence of samples from the model.

    Args:
    model: the diffusion model
    img: Tensor. The initial input tensor.
    image_size: int. The size of the image (height and width).
    timestep: int. The total number of timesteps to iterate through.
    batch_size: int, optional. The number of images in the batch. Default is 64.
    channels: int, optional. The number of image channels. Default is 1.

    Returns:
    List[Tensor]. A list of sampled tensors at each timestep.
    """
    return p_sample_loop(model, img, shape=(batch_size, channels, image_size, image_size), timesteps=timestep)

# %% [markdown]
# ##Train

# %% [markdown]
# The model has been trained for 50 epochs using an Adam optimizer and a scheduler in order to adapt the learning rate during the training procedure.

# %%
diffusion_model = Unet(
    dim = global_var["image_size"],
    channels = global_var["channels"],
    dim_mults = global_var["dim_mults"],
    with_time_emb = global_var["with_time_emb"],
    resnet_block_groups = global_var["resnet_block_groups"],
    convnext_mult = global_var["convnext_mult"],
).to(device)

#diffusion_model.load_state_dict(torch.load('/content/Neural_Network/models/diffusion_model_fer_1.pth'))

diffusion_model.load_state_dict(torch.load('/content/Neural_Network/models/diffusion_model_mnist.pth'))
# Out:
# <ipython-input-20-71fd88cb887a>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   diffusion_model.load_state_dict(torch.load('/content/Neural_Network/models/diffusion_model_mnist.pth'))
# <All keys matched successfully>

# %%
optimizer = Adam(diffusion_model.parameters(), lr = global_var['lr'])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = global_var['patience'], factor = global_var['factor'])

for epoch in range(global_var['epochs']):
    for step, batch in enumerate(dataloader):
      optimizer.zero_grad()

      batch_size = batch[0].shape[0]
      batch = batch[0].to(device)

      t = torch.randint(0, global_var["timesteps"], (batch_size,), device=device).long()
      noise=torch.randn_like(batch)
      x_noisy = q_sample(x_start=batch, t=t, noise=noise)
      predicted_noise = diffusion_model(x_noisy[0], t)

      loss = F.smooth_l1_loss(noise, predicted_noise)

      if step % 200 == 0:
        print("Epoch: " + str(epoch)+ "   Loss:", loss.item())

      loss.backward()
      optimizer.step()

    scheduler.step(loss)

# %%
#path = '/content/diffusion_model_fer_1.pth'

#torch.save(diffusion_model.state_dict(), path)

# %%
#!git config --global user.name "FedericoRaschiatore0123"
#!git config --global user.email "raschiatore.2071132@studenti.uniroma1.it"

#!git clone https://github.com/FedericoRaschiatore0123/Neural_Network.git

#!mv /content/diffusion_model_fer_1.pth /content/Neural_Network/models

#%cd /content/Neural_Network

#!git add .
#!git commit -m "Added diffusion model"

#!git remote rm origin
#!git remote add origin https://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@github.com/FedericoRaschiatore0123/Neural_Network.git
#!git push -u origin main

#%cd ..

# %%
with torch.no_grad():
  batch = next(iter(dataloader))[0]
  noise=torch.randn_like(batch).to(device)
  sample_data = sample(
        diffusion_model,
        noise,
        image_size=global_var["image_size"],
        timestep = global_var['timesteps'],
        batch_size=global_var["batch_size"],
        channels=global_var["channels"]
      )
  show_batch(sample_data[-1].cpu().detach())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Discriminator
# In this section is implemented the discriminator model that is based on a VIT architecture. The aim of this model is distinguish between real images and generated images, so this is a binary classification problem.
# The architecture is inspired by the paper Dosovitskiy et al (2021) (https://arxiv.org/pdf/2010.11929.pdf) but adapted to the problem of binary classification.
#
#
# The pretraining procedure is done as in an adversarial network, giving in input real images and fake images generated by the pretrained diffusion model. The model is teached to distinguish between the real images and the fake ones.
#
#
# <p align="center">
#     <img src="https://kikaben.com/understanding-generative-adversarial-networks/images/thumbnail.png" width="600" />
# </p>

# %% [markdown]
# ##ViT

# %%
class PatchEmbedding(nn.Module):
    """
    Patch Embedding for ViT.

    Args:
    in_channels: int. Number of input channels in the image.
    patch_size: int. Size of the patch to divide the image into.
    emb_size: int, optional. Size of the embedding. Default is 16.

    Returns:
    Tensor. The embedded patches of the input image.
    """
    def __init__(self, in_channels, patch_size,  emb_size = 16):
        self.patch_size = patch_size
        super().__init__()
        self.projection = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1 = patch_size, p2 = patch_size),
            nn.LayerNorm(patch_size * patch_size * in_channels),
            nn.Linear(patch_size * patch_size * in_channels, emb_size),
            nn.LayerNorm(emb_size),
        )

    def forward(self, x):
        x = self.projection(x)
        return x

# %%
class DiscResidual(nn.Module):
    """
    Residual connection wrapper.

    Args:
    fn: nn.Module. The function to apply before adding the input to the output.

    Returns:
    Tensor. The output of the function added to the input tensor.
    """
    def __init__(self, fn):
        super().__init__()
        self.fn=fn

    def forward(self, x, *args, **kwargs):
        return self.fn(x, *args, **kwargs) + x


class DiscPreNorm(nn.Module):
    """
    Pre-normalization wrapper.

    Args:
    dim: int. Dimensionality of the input tensor.
    fn: nn.Module. The function to apply after normalization.

    Returns:
    Tensor. The normalized input passed through the function.
    """
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

# %%
class DiscAttention(nn.Module):
  """
    Multi-head self-attention mechanism.

    Args:
    emb_dim: int. Embedding dimensionality.
    num_heads: int. Number of attention heads.
    dropout: float. Dropout rate.

    Returns:
    Tensor. The output of the attention mechanism.
    """
  def __init__(self, emb_dim, num_heads, dropout):
    super(DiscAttention, self).__init__()
    self.emb_dim=emb_dim
    self.num_heads = num_heads

    self.attention = nn.MultiheadAttention(self.emb_dim, self.num_heads, dropout=dropout)

    self.q = nn.Linear(emb_dim, emb_dim)
    self.k = nn.Linear(emb_dim, emb_dim)
    self.v = nn.Linear(emb_dim, emb_dim)

  def forward(self, x):
    q = self.q(x)
    k = self.k(x)
    v = self.v(x)
    attention, attention_weights = self.attention(q, k, v)
    return attention

# %%
class ViT(nn.Module):
  """
  Vision Transformer (ViT) model.

  Args:
  emb_dim: int. Embedding dimensionality.
  hidden_dim: int. Dimensionality of the hidden layer in the MLP block.
  out_dim: int. Dimensionality of the output layer.
  channels: int. Number of input channels in the image.
  patch_size: int. Size of the patch to divide the image into.
  n_layers: int, optional. Number of transformer layers. Default is 3.
  img_size: int, optional. Size of the input image (height and width). Default is 32.
  dropout: float, optional. Dropout rate. Default is 0.1.
  num_heads: int, optional. Number of attention heads. Default is 4.

  Returns:
  Tensor. The output classification probabilities.
  """
  def __init__(self, emb_dim, hidden_dim, out_dim, channels, patch_size,  n_layers = 3,  img_size=32, dropout=0.1, num_heads = 4):
    super(ViT, self).__init__()
    self.emb_dim = emb_dim
    self.num_heads = num_heads
    self.hidden_dim = hidden_dim
    self.dropout = dropout
    self.channels = channels
    self.img_width = img_size
    self.img_height = img_size
    self.n_layers = n_layers

    self.patch_embedding = PatchEmbedding(channels, patch_size = patch_size,  emb_size = emb_dim)

    # Learnable params
    num_patches = (emb_dim // patch_size) ** 2
    self.positional_emb = nn.Parameter(torch.randn(1, num_patches + 1, emb_dim))
    self.cls_token = nn.Parameter(torch.rand(1, 1, emb_dim))

    self.layers = nn.ModuleList([])
    for _ in range(n_layers):
      block = nn.Sequential(

          DiscResidual(DiscPreNorm(emb_dim, DiscAttention(emb_dim, num_heads, dropout))),

          DiscResidual(DiscPreNorm(emb_dim, nn.Sequential(nn.Linear(emb_dim, hidden_dim),
                                                  nn.LeakyReLU(),
                                                  nn.Dropout(dropout),
                                                  nn.Linear(hidden_dim, emb_dim),
                                                  nn.Dropout(dropout)
                                              )))
      )
      self.layers.append(block)

    self.classification_head = nn.Sequential(nn.LayerNorm(emb_dim* (num_patches + 1)), nn.Linear(emb_dim* (num_patches + 1), out_dim))
    self.sigmoid = nn.Sigmoid()
    self.projection = nn.Sequential(
            Rearrange('b h p -> b (h p)')
        )

  def forward(self, batch):

      x = self.patch_embedding(batch)
      b, n, _ = x.shape

      # Add cls token to inputs
      cls_tokens = repeat(self.cls_token, '1 1 d -> b 1 d', b = b)
      x = torch.cat((cls_tokens,x), dim=1)
      x += self.positional_emb[:, :(n+1), :]
      for layer in self.layers:
        x = layer(x)
      x = self.projection(x)
      return self.sigmoid(self.classification_head(x[:, :]))

# %% [markdown]
# ##Training
#
# This model has been trained for only 1 epoch because I have seen that it learn very quickly for this reason i decided to make a simple training and fine tune it during the Adversarial distillation training.
# I also used:
# * an Adam optimizer
# * scheduler in order to adapt the learning rate during the training procedure.
#
# The loss used is the Binary Cross entropy loss from pytorch that is the loss usually used for the Bynary classification task

# %%
losses = []

discriminator_model =ViT( emb_dim = global_var["embed_dim"],
                          hidden_dim = global_var["hidden_dim"],
                          out_dim = global_var["out_dim"],
                          channels = global_var["channels"],
                          patch_size = global_var["patch_size"],
                          n_layers = global_var["n_layers"],
                          img_size = global_var["image_size"],
                          dropout = global_var["dropout"],
                          num_heads = global_var["num_heads"],
                      ).to(device)

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(discriminator_model.parameters(), lr=global_var['vit_lr'])
batch_size = global_var['batch_size']
channels = global_var['channels']
image_size = global_var['image_size']

for epoch in range(global_var['vit_epochs']):

    for step, batch in enumerate(dataloader):

        if step == global_var["number_of_steps"]:
          break

        optimizer.zero_grad()

        t = torch.randint(0, timesteps, (batch[0].shape[0],), device=device).long().to(device)

        noise=torch.randn_like(batch[0]).to(device)
        x_noisy = q_sample(x_start=batch[0].to(device), t=t, noise=noise)

        predicted_noise = diffusion_model(x_noisy[0], t)

        with torch.no_grad():
          fake_data = sample( diffusion_model, x_noisy[0], image_size, timestep=timesteps,  batch_size=batch_size, channels=channels)

        real_data = batch

        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        if real_data[0].shape[0] == batch_size:

          output_real = discriminator_model(real_data[0].to(device))
          loss_real = criterion(output_real, real_labels)
        else:
          break

        output_fake = discriminator_model(fake_data[-1].detach())
        loss_fake = criterion(output_fake, fake_labels)

        total_loss = loss_real + loss_fake
        print(loss_real)
        print(loss_fake)
        print("Epoch: " + str(epoch)+ "   Loss:", total_loss)

        total_loss.backward()
        optimizer.step()
# Out:
# tensor(0.6032, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.8289, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.4321, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(1.1369, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3468, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.4838, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.7702, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5743, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.3446, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.3952, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.9334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.3286, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.3574, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.9484, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.3058, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.4325, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.7111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1436, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.6186, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5577, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1763, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.7202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3604, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.0806, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.7819, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4170, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1989, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.7425, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3701, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1127, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.6570, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4753, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1323, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.4651, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.7158, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1809, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.3481, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.7705, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1186, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.3230, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.8086, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1316, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.4106, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.5790, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(0.9896, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.4552, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.6733, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(1.1284, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.4990, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.4917, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(0.9907, device='cuda:0', grad_fn=<AddBackward0>)
# tensor(0.5381, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# tensor(0.3836, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0   Loss: tensor(0.9217, device='cuda:0', grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-5718335410d0> in <cell line: 7>()
#      22
#      23         with torch.no_grad():
# ---> 24           fake_data = sample( diffusion_model, x_noisy[0], image_size, timestep=timesteps,  batch_size=batch_size, channels=channels)
#      25
#      26         real_data = batch
#
# <ipython-input-18-70b1fb1ba32d> in sample(model, img, image_size, timestep, batch_size, channels)
#      69     List[Tensor]. A list of sampled tensors at each timestep.
#      70     """
# ---> 71     return p_sample_loop(model, img, shape=(batch_size, channels, image_size, image_size), timesteps=timestep)
#
# <ipython-input-18-70b1fb1ba32d> in p_sample_loop(model, img, shape, timesteps)
#      49
#      50     for i in reversed(range(0, timesteps)):
# ---> 51         img = p_sample(model, img, torch.full((b,), i, device=device, dtype=torch.long), i)
#      52         imgs.append(img)
#      53     return imgs
#
# <ipython-input-18-70b1fb1ba32d> in p_sample(model, x, t, t_index)
#      19
#      20     model_mean = sqrt_recip_alphas_t * (
# ---> 21         x - betas_t * model(x, t) / sqrt_one_minus_alphas_cumprod_t
#      22     )
#      23
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-17-74f34e7914f1> in forward(self, x, time)
#     103             x = block2(x, t)
#     104
# --> 105             x = attn(x)
#     106             h.append(x)
#     107             x = downsample(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-13-3951b28d1ef1> in forward(self, x, *args, **kwargs)
#      39
#      40     def forward(self, x, *args, **kwargs):
# ---> 41         return self.fn(x, *args, **kwargs) + x
#      42
#      43 def Upsample(dim):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-13-3951b28d1ef1> in forward(self, x)
#      83     def forward(self, x):
#      84         x = self.norm(x)
# ---> 85         return self.fn(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-16-02e1f7943563> in forward(self, x)
#      73         out = torch.einsum("b h d e, b h d n -> b h e n", context, q)
#      74         out = rearrange(out, "b h c (x y) -> b (h c) x y", h=self.heads, x=h, y=w)
# ---> 75         return self.to_out(out)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     217     def forward(self, input):
#     218         for module in self:
# --> 219             input = module(input)
#     220         return input
#     221
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/normalization.py in forward(self, input)
#     286
#     287     def forward(self, input: Tensor) -> Tensor:
# --> 288         return F.group_norm(
#     289             input, self.num_groups, self.weight, self.bias, self.eps)
#     290
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in group_norm(input, num_groups, weight, bias, eps)
#    2604         raise RuntimeError(f"Expected at least 2 dimensions for input tensor but received {input.dim()}")
#    2605     _verify_batch_size([input.size(0) * input.size(1) // num_groups, num_groups] + list(input.size()[2:]))
# -> 2606     return torch.group_norm(input, num_groups, weight, bias, eps, torch.backends.cudnn.enabled)
#    2607
#    2608
#
# KeyboardInterrupt:

# %%
#path = '/content/discriminator_model_fer_1.pth'

#torch.save(discriminator_model.state_dict(), path)
#!git config --global user.name "FedericoRaschiatore0123"
#!git config --global user.email "raschiatore.2071132@studenti.uniroma1.it"

#!git clone https://github.com/FedericoRaschiatore0123/Neural_Network.git

#!mv /content/discriminator_model_fer_1.pth /content/Neural_Network/models

#%cd /content/Neural_Network

#!git add .
#!git commit -m "Added diffusion model"

#!git remote rm origin
#!git remote add origin https://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@github.com/FedericoRaschiatore0123/Neural_Network.git
#!git push -u origin main

#%cd ..
# Out:
# /content/Neural_Network
# [main 1228887] Added diffusion model
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  rewrite models/discriminator_model_fer_1.pth (91%)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 467.22 KiB | 12.98 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/FedericoRaschiatore0123/Neural_Network.git
#    b0aef23..1228887  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# /content

# %% [markdown]
# # ADD Training
#
# The training procedure is splitted in 2 different part.
#
# The first part is a pretraining procedure that given in input to the teacher and to the student model the same noised image in order to pretrain the student.
#
# The second part is the main part in which is implemneted the ADD training procedure. The student take in input the noised image, instead the teacher will take in input the noised output of the student. At the end the two outputs will be compared in the distillation loss and the result of the ADD-student denoise will pass in the Discriminator that will compute the discriminator loss. The two losses will be summed up and the resulting total loss will be backpropagated and the parameters of the model will be updated.
#
# The discriminator model is updated every 10 steps in order to avoid that the discriminator learn too fast compared to the generator

# %% [markdown]
# The student timestep number is set to 4 as in the paper.
#
# The teacher for the pretrain procedure used the original timesteps number from the original diffusion model instead for the ADD training the number of timestep is set to teacher_timesteps - 300.
#
# The distillation weighting factor value is the one proposed in the paper l = 2.5.
#
# I decided to insert a regularization term to avoid mode collapse in the second trainng phase. The regularization strategy that i decided to use is the following:
#
# \begin{equation}
# \mathcal{L}_{\text{diversity}} = - \frac{1}{N} \sum_{i=1}^{N} \left| x_i - \mu \right|
# \end{equation}

# %% [markdown]
# The input size is fixed to 32 x 32 x 1 for both the MNIST dataset and for the FER dataset.

# %%
image_size = global_var['image_size']
channels = global_var['channels']
batch_size = global_var['batch_size']
student_timesteps = global_var['student_timesteps']
teacher_timesteps = global_var['teacher_timesteps']

disc_loss = nn.BCELoss()
dis_loss = nn.MSELoss()
l = global_var["lambda"]
regularization_term = global_var['regularization_term']

# %% [markdown]
# In this section are imported the pretrained models.
#
# The teacher model have been set to evaluation mode, instead the discriminator and the student model have been set to train mode in order to update the weigths of this models.

# %%
# Load the teacher_model
teacher_model =  Unet(  dim = global_var["image_size"],
                        channels = global_var["channels"],
                        dim_mults = global_var["dim_mults"],
                        with_time_emb = global_var["with_time_emb"],
                        resnet_block_groups = global_var["resnet_block_groups"],
                        convnext_mult = global_var["convnext_mult"])

teacher_model.load_state_dict(torch.load(global_var['teacher_path']))
teacher_model.eval()
teacher_model.to(device)

# Load the discriminator_model
discriminator_model = ViT(  emb_dim = global_var["embed_dim"],
                            hidden_dim = global_var["hidden_dim"],
                            out_dim = global_var["out_dim"],
                            channels = global_var["channels"],
                            patch_size = global_var["patch_size"],
                            n_layers = global_var["n_layers"],
                            img_size = global_var["image_size"],
                            dropout = global_var["dropout"],
                            num_heads = global_var["num_heads"])

discriminator_model.load_state_dict(torch.load(global_var['discriminator_path']))
discriminator_model.train()
discriminator_model.to(device)

# Load the student_model
student_model =  Unet(  dim = global_var["image_size"],
                        channels = global_var["channels"],
                        dim_mults = global_var["dim_mults"],
                        with_time_emb = global_var["with_time_emb"],
                        resnet_block_groups = global_var["resnet_block_groups"],
                        convnext_mult = global_var["convnext_mult"])

student_model.load_state_dict(torch.load(global_var['student_path']))
student_model.train()
student_model.to(device)
# Out:
# <ipython-input-28-d1617c282469>:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher_model.load_state_dict(torch.load(global_var['teacher_path']))
# <ipython-input-28-d1617c282469>:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   discriminator_model.load_state_dict(torch.load(global_var['discriminator_path']))
# <ipython-input-28-d1617c282469>:36: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student_model.load_state_dict(torch.load(global_var['student_path']))
# Unet(
#   (init_conv): Conv2d(1, 20, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#   (time_mlp): Sequential(
#     (0): SinusoidalPositionEmbeddings()
#     (1): Linear(in_features=32, out_features=128, bias=True)
#     (2): GELU(approximate='none')
#     (3): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (downs): ModuleList(
#     (0): ModuleList(
#       (0): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=32, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(20, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=32, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Residual(
#         (fn): PreNorm(
#           (fn): LinearAttention(
#             (to_qkv): Conv2d(32, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Sequential(
#               (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#               (1): GroupNorm(1, 32, eps=1e-05, affine=True)
#             )
#           )
#           (norm): GroupNorm(1, 32, eps=1e-05, affine=True)
#         )
#       )
#       (3): Conv2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (1): ModuleList(
#       (0): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=64, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=64, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Residual(
#         (fn): PreNorm(
#           (fn): LinearAttention(
#             (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#               (1): GroupNorm(1, 64, eps=1e-05, affine=True)
#             )
#           )
#           (norm): GroupNorm(1, 64, eps=1e-05, affine=True)
#         )
#       )
#       (3): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (2): ModuleList(
#       (0): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=128, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=128, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Residual(
#         (fn): PreNorm(
#           (fn): LinearAttention(
#             (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#             )
#           )
#           (norm): GroupNorm(1, 128, eps=1e-05, affine=True)
#         )
#       )
#       (3): Conv2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (3): ModuleList(
#       (0): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=256, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=256, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Residual(
#         (fn): PreNorm(
#           (fn): LinearAttention(
#             (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#               (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#             )
#           )
#           (norm): GroupNorm(1, 256, eps=1e-05, affine=True)
#         )
#       )
#       (3): Identity()
#     )
#   )
#   (ups): ModuleList(
#     (0): ModuleList(
#       (0): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=128, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=128, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Residual(
#         (fn): PreNorm(
#           (fn): LinearAttention(
#             (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Sequential(
#               (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#             )
#           )
#           (norm): GroupNorm(1, 128, eps=1e-05, affine=True)
#         )
#       )
#       (3): ConvTranspose2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (1): ModuleList(
#       (0): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=64, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=64, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Residual(
#         (fn): PreNorm(
#           (fn): LinearAttention(
#             (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Sequential(
#               (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#               (1): GroupNorm(1, 64, eps=1e-05, affine=True)
#             )
#           )
#           (norm): GroupNorm(1, 64, eps=1e-05, affine=True)
#         )
#       )
#       (3): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (2): ModuleList(
#       (0): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=32, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): UNet_ResNet(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=128, out_features=32, bias=True)
#         )
#         (block1): UNet_Block(
#           (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): UNet_Block(
#           (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Residual(
#         (fn): PreNorm(
#           (fn): LinearAttention(
#             (to_qkv): Conv2d(32, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Sequential(
#               (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#               (1): GroupNorm(1, 32, eps=1e-05, affine=True)
#             )
#           )
#           (norm): GroupNorm(1, 32, eps=1e-05, affine=True)
#         )
#       )
#       (3): ConvTranspose2d(32, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#   )
#   (mid_block1): UNet_ResNet(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (block1): UNet_Block(
#       (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): UNet_Block(
#       (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (mid_attn): Residual(
#     (fn): PreNorm(
#       (fn): Attention(
#         (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (norm): GroupNorm(1, 256, eps=1e-05, affine=True)
#     )
#   )
#   (mid_block2): UNet_ResNet(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (block1): UNet_Block(
#       (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): UNet_Block(
#       (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): GroupNorm(4, 256, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (final_conv): Sequential(
#     (0): UNet_ResNet(
#       (block1): UNet_Block(
#         (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): UNet_Block(
#         (proj): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): GroupNorm(4, 32, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Identity()
#     )
#     (1): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## Pretrain

# %%
epochs = global_var["pretrain_epochs"]

student_optimizer = Adam(student_model.parameters(), lr=global_var["pretrain_lr"])
scheduler_student = torch.optim.lr_scheduler.ReduceLROnPlateau(student_optimizer,'min', patience=global_var["pretrain_patience"], factor=global_var["pretrain_scheduler_factor"])

losses=[]

for epoch in range(epochs):

    for step, batch in enumerate(dataloader):
      if step == global_var["number_of_steps"]:
        break

      student_optimizer.zero_grad()

      batch_size = batch[0].shape[0]
      batch = batch[0].to(device)

      t_student = torch.randint(0, teacher_timesteps, (batch_size,), device=device).long()
      t_teacher = t_student

      noise = torch.randn_like(batch)
      x_noisy_student = q_sample(x_start=batch, t=t_student, noise=noise)

      student_data = sample( student_model, x_noisy_student[0] , image_size, timestep=student_timesteps,  batch_size=batch_size, channels=channels)

      with torch.no_grad():
        number_of_timsteps = int(teacher_timesteps ) - 300
        teacher_data = sample( teacher_model, x_noisy_student[0], image_size, timestep=number_of_timsteps,  batch_size=batch_size, channels=channels)

      if step % 10 == 0:
        #show the results
        image_size = global_var['image_size']
        random_index = random.randint(0, global_var['batch_size']-1)
        image_data0 = batch[random_index].cpu().numpy().reshape(image_size, image_size, channels)
        image_data1 = student_data[-1][random_index].cpu().detach().numpy().reshape(image_size, image_size, channels)
        image_data3 = teacher_data[-1][random_index].cpu().numpy().reshape(image_size, image_size, channels)
        plt.imshow(image_data0)
        plt.show()
        plt.imshow(image_data1)
        plt.show()
        plt.imshow(image_data3)
        plt.show()

      distill_loss = F.smooth_l1_loss(teacher_data[-1] , student_data[-1])
      loss = l*distill_loss
      losses.append(loss)

      print("Epoch: " + str(epoch) +  "  Distillation Loss:" + str(distill_loss))

      loss.backward()
      student_optimizer.step()

    scheduler_student.step(loss)
# Out:
# Epoch: 0  Distillation Loss:tensor(0.0585, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0336, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0335, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0326, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0309, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0285, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0260, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0261, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0231, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0236, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0181, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0199, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0185, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0183, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0165, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0167, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0156, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0148, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0140, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0134, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0124, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0123, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0120, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0117, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0121, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0109, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0113, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0121, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0110, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0112, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0110, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0106, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0109, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0103, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0110, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0098, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0097, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0100, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0103, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0104, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0101, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0100, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0110, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0099, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0091, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0093, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0103, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0104, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0085, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 0  Distillation Loss:tensor(0.0103, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0095, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0092, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0096, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0102, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0084, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0091, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0083, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0089, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0090, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0087, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0095, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0087, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0091, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0088, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0095, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0099, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0099, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0090, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0082, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0094, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0086, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0086, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0088, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0097, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0089, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0084, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0087, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0079, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0081, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0093, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0083, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0083, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0090, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0094, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0095, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0083, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0087, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0086, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0083, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0085, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0091, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0092, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0080, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0092, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0101, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0089, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0082, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0076, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0081, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 1  Distillation Loss:tensor(0.0086, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0080, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0088, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0087, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0102, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0083, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0089, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0088, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0077, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0080, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0082, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0077, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0094, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0089, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0094, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0093, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0085, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0091, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0083, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0079, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0089, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# Epoch: 2  Distillation Loss:tensor(0.0090, device='cuda:0', grad_fn=<SmoothL1LossBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-ca0e2769fd3b> in <cell line: 8>()
#      27       with torch.no_grad():
#      28         number_of_timsteps = int(teacher_timesteps ) - 300
# ---> 29         teacher_data = sample( teacher_model, x_noisy_student[0], image_size, timestep=number_of_timsteps,  batch_size=batch_size, channels=channels)
#      30
#      31       if step % 10 == 0:
#
# <ipython-input-18-70b1fb1ba32d> in sample(model, img, image_size, timestep, batch_size, channels)
#      69     List[Tensor]. A list of sampled tensors at each timestep.
#      70     """
# ---> 71     return p_sample_loop(model, img, shape=(batch_size, channels, image_size, image_size), timesteps=timestep)
#
# <ipython-input-18-70b1fb1ba32d> in p_sample_loop(model, img, shape, timesteps)
#      49
#      50     for i in reversed(range(0, timesteps)):
# ---> 51         img = p_sample(model, img, torch.full((b,), i, device=device, dtype=torch.long), i)
#      52         imgs.append(img)
#      53     return imgs
#
# <ipython-input-18-70b1fb1ba32d> in p_sample(model, x, t, t_index)
#      19
#      20     model_mean = sqrt_recip_alphas_t * (
# ---> 21         x - betas_t * model(x, t) / sqrt_one_minus_alphas_cumprod_t
#      22     )
#      23
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-17-74f34e7914f1> in forward(self, x, time)
#      94         x = self.init_conv(x)
#      95
# ---> 96         t = self.time_mlp(time) if exists(self.time_mlp) else None
#      97
#      98         h = []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     217     def forward(self, input):
#     218         for module in self:
# --> 219             input = module(input)
#     220         return input
#     221
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     115
#     116     def forward(self, input: Tensor) -> Tensor:
# --> 117         return F.linear(input, self.weight, self.bias)
#     118
#     119     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ## ADD train

# %%
torch.cuda.empty_cache()

# %%
epochs = global_var["add_train_epochs"]

student_optimizer = Adam(student_model.parameters(), lr=global_var["student_lr"])
discriminator_optimizer = Adam(discriminator_model.parameters(), lr=global_var["discriminator_lr"])
scheduler_student = torch.optim.lr_scheduler.ReduceLROnPlateau(student_optimizer, 'min', patience=global_var["add_patience"], factor=global_var["add_factor"])
scheduler_discriminator = torch.optim.lr_scheduler.ReduceLROnPlateau(discriminator_optimizer, 'min', patience=global_var["add_patience"], factor=global_var["add_factor"])

losses=[]

for epoch in range(epochs):

    for step, batch in enumerate(dataloader):
      if step == global_var["number_of_steps"]:
        break

      student_optimizer.zero_grad()

      batch_size = batch[0].shape[0]
      batch = batch[0].to(device)

      t_student = torch.randint(0, teacher_timesteps, (batch_size,), device=device).long()
      t_teacher = torch.randint(0, teacher_timesteps, (batch_size,), device=device).long()

      noise = torch.randn_like(batch)
      x_noisy_student = q_sample(x_start=batch, t=t_student, noise=noise)

      student_data = sample( student_model, x_noisy_student[0] , image_size, timestep=4,  batch_size=batch_size, channels=channels)

      real_labels = torch.ones(batch_size, 1).to(device)
      fake_labels = torch.zeros(batch_size, 1).to(device)

      output_real = discriminator_model(batch)
      loss_real = disc_loss(output_real, real_labels)

      output_fake = discriminator_model(student_data[-1])
      loss_fake = disc_loss(output_fake, fake_labels)

      if step % 20 ==0:

        adversarial_loss = loss_real + loss_fake
        adversarial_loss.backward(retain_graph=True)
        discriminator_optimizer.step()
        discriminator_optimizer.zero_grad()

      print("Epoch: " + str(epoch) , " Loss Real:" + str(loss_real) )
      print("Epoch: " + str(epoch) , " Loss Fake:" + str(loss_fake) )

      output_fake = discriminator_model(student_data[-1])
      loss_f = disc_loss(output_fake, real_labels)

      x_noisy_teacher = q_sample(x_start=student_data[-1], t=t_teacher, noise=noise)

      with torch.no_grad():
        number_of_timsteps = int(teacher_timesteps ) - 300
        teacher_data = sample( teacher_model, x_noisy_student[0], image_size, timestep=number_of_timsteps,  batch_size=batch_size, channels=channels)

      if step % 10 == 0:
          image_size = global_var['image_size']
          random_index = random.randint(0, global_var['batch_size']-1)
          image_data0 = batch[random_index].cpu().numpy().reshape(image_size, image_size, channels)
          image_data1 = student_data[-1][random_index].cpu().detach().numpy().reshape(image_size, image_size, channels)
          image_data3 = teacher_data[-1][random_index].cpu().numpy().reshape(image_size, image_size, channels)
          plt.imshow(image_data0)
          plt.show()
          plt.imshow(image_data1)
          plt.show()
          plt.imshow(image_data3)
          plt.show()

      distill_loss = dis_loss(teacher_data[-1] , student_data[-1])

      diversity_loss = -torch.mean(torch.abs(student_data[-1]  - student_data[-1].mean(dim=0)))
      print("Regularization Term    " + str(diversity_loss))
      loss = l*distill_loss + loss_f + diversity_loss* 0.1

      losses.append(loss)

      print("Epoch: " + str(epoch) + "  Total Loss:", str(loss), "  Distillation Loss:" + str(distill_loss), " Adversarial Loss:" + str(loss_fake) )

      loss.backward()
      student_optimizer.step()

    scheduler_student.step(loss)
    scheduler_discriminator.step(adversarial_loss)
# Out:
# Epoch: 0  Loss Real:tensor(0.7091, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(1.3488, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2242, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.5250, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0178, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(1.3488, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.8145, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(0.6251, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2420, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(1.0870, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0183, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(0.6251, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7704, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(0.8120, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2252, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.8000, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(0.8120, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7906, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(0.9299, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2470, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.6757, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0174, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(0.9299, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6988, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(1.3575, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2217, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.4606, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0186, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(1.3575, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6453, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(1.7597, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2320, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.2627, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(1.7597, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(2.0504, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2261, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.1921, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.0504, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7579, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(2.2927, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2196, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.1564, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0184, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.2927, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6661, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(2.6629, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2131, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.1161, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0193, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.6629, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7874, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.0746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2230, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0847, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6658, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.1654, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2230, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0781, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1654, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6507, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.3497, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2213, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0711, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.3497, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.8357, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4389, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2190, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0719, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0237, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4389, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6018, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.5717, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1979, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0739, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0257, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.5717, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6585, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.6202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2341, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0694, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0258, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.6202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.6837, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2034, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0738, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.6837, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6588, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.7816, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1958, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0715, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0270, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.7816, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6339, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.8230, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2096, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0674, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.8230, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7477, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.8860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2121, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0647, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0257, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.8860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7271, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.9086, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2074, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0597, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0237, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.9086, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6511, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(4.0208, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2192, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0563, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0242, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(4.0208, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6599, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.8678, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2056, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0556, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.8678, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5933, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.8378, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2318, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0604, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0246, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.8378, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5906, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.7529, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2118, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0723, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0272, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.7529, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5526, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.6276, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2265, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0755, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0281, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.6276, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5577, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.3525, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2160, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0796, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0250, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.3525, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6431, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.5647, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2051, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0711, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0246, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.5647, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5744, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.3585, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2326, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0863, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0277, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.3585, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5924, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4888, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1862, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0772, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0253, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4888, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.3501, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2143, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0839, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0271, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.3501, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5686, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.3356, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2189, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0781, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0245, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.3356, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6416, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4092, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2187, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0727, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0238, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4092, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6023, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4220, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2189, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0721, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4220, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6726, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4871, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2140, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0645, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4871, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6656, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.3852, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2005, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0806, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0264, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.3852, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6677, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4007, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1972, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0783, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0254, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4007, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6687, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4826, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2073, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0759, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0256, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4826, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.5696, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2059, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0681, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0236, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.5696, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6228, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.6408, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2094, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0666, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0238, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.6408, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.7015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.6009, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1931, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0738, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0259, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.6009, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6911, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.5960, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2029, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0713, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0255, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.5960, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6491, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4798, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2237, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0683, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4798, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5372, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2162, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0667, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5240, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.4385, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2043, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0740, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0240, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.4385, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6703, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.3443, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2199, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0740, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0233, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.3443, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5888, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.2330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2330, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0711, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0208, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.2330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.5953, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.2662, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2047, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0765, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.2662, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6676, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.1769, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2307, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0766, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1769, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6076, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.2848, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2246, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0688, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.2848, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Real:tensor(0.6753, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 0  Loss Fake:tensor(3.0509, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2216, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0  Total Loss: tensor(0.0831, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0509, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5829, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.2413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2177, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0722, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0207, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.2413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6744, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1182, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2309, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0832, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0239, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1182, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4645, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0492, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2377, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0785, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0492, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2085, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0886, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2191, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.1005, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0234, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5760, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8009, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2237, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.1021, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8009, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6384, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.7560, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2413, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.1068, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.7560, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4814, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8093, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2300, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.1018, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0232, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8093, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4748, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.7869, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2219, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0991, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.7869, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5145, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8597, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2349, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0926, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0212, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8597, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6024, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2240, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0997, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6758, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8255, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2007, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.1019, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0226, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8255, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.7699, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1948, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.1057, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.7699, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5799, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8050, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2082, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0993, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0219, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8050, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.7185, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2338, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0937, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5365, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9151, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2284, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0934, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0221, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9151, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4323, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9572, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1994, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0946, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0229, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9572, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5040, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0901, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2323, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0838, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0229, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0901, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.7238, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0809, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2200, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0842, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0809, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6235, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9568, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2537, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0809, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0193, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9568, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6325, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0972, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2253, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0828, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0225, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0972, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5209, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1642, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2212, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0788, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0218, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1642, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6467, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9509, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2237, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0880, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9509, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4876, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2028, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0826, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5757, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0243, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2188, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0866, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0214, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0243, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5870, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0062, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2036, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0852, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0208, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0062, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.3768, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2328, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0804, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4910, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.8983, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2046, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0909, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8983, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5966, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.7883, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2318, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0932, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.7883, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5478, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9227, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2338, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0900, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9227, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.6345, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9233, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2467, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0859, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9233, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5226, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9810, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2328, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0828, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9810, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5396, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9947, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1961, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0906, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9947, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5476, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9997, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2221, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0794, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0188, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9997, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4521, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2168, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0930, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4546, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9966, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2341, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0809, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9966, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5772, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(2.9442, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2162, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0831, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9442, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5831, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1719, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2251, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0727, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1719, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1991, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2151, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0732, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1991, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5264, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1876, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2401, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0761, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0217, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1876, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4458, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1675, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2333, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0712, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1675, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4634, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1822, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2118, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0736, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1822, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.5210, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.1470, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2222, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0758, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0209, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1470, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4676, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Fake:tensor(3.0943, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2256, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 1  Total Loss: tensor(0.0790, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0943, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 1  Loss Real:tensor(0.4385, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# ...
# Regularization Term    tensor(-0.2079, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0875, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0196, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9102, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3417, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8501, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2123, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0905, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0191, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8501, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3177, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9801, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2424, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0737, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0172, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9801, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3620, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9521, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2298, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0806, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0182, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9521, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3521, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8400, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2364, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0924, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8400, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8988, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2299, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0888, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8988, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3303, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8242, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2147, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0946, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8242, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3636, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8058, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2474, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0927, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0203, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8058, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3304, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8973, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2460, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0836, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0185, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8973, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3353, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2208, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0906, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3724, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.8610, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2359, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0881, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0187, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.8610, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3255, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9421, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2238, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0840, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9421, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3715, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2389, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0798, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3298, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2145, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0897, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3364, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0810, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2721, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0658, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0810, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.2878, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0217, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2332, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0827, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0217, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3284, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0277, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.1994, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0810, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0277, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.2902, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.1539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2353, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0728, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.1539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.4041, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0084, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2287, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0778, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0195, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0084, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3817, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0687, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2451, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0746, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0194, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0687, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3440, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0166, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0769, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0189, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0166, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9442, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2388, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0829, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0197, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9442, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3554, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0771, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2320, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0807, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0771, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0437, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2347, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0797, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0437, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3273, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0078, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2419, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0789, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0198, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0078, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3406, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(3.0095, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2534, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0821, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0210, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(3.0095, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.3043, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9051, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2543, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0865, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9051, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Real:tensor(0.4107, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 4  Loss Fake:tensor(2.9204, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Regularization Term    tensor(-0.2496, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 4  Total Loss: tensor(0.0890, device='cuda:0', grad_fn=<AddBackward0>)   Distillation Loss:tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward0>)  Adversarial Loss:tensor(2.9204, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 5  Loss Real:tensor(0.3822, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# Epoch: 5  Loss Fake:tensor(2.9740, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-801bd92bce13> in <cell line: 10>()
#      53       with torch.no_grad():
#      54         number_of_timsteps = int(teacher_timesteps ) - 300
# ---> 55         teacher_data = sample( teacher_model, x_noisy_student[0], image_size, timestep=number_of_timsteps,  batch_size=batch_size, channels=channels)
#      56
#      57       if step % 10 == 0:
#
# <ipython-input-18-70b1fb1ba32d> in sample(model, img, image_size, timestep, batch_size, channels)
#      69     List[Tensor]. A list of sampled tensors at each timestep.
#      70     """
# ---> 71     return p_sample_loop(model, img, shape=(batch_size, channels, image_size, image_size), timesteps=timestep)
#
# <ipython-input-18-70b1fb1ba32d> in p_sample_loop(model, img, shape, timesteps)
#      49
#      50     for i in reversed(range(0, timesteps)):
# ---> 51         img = p_sample(model, img, torch.full((b,), i, device=device, dtype=torch.long), i)
#      52         imgs.append(img)
#      53     return imgs
#
# <ipython-input-18-70b1fb1ba32d> in p_sample(model, x, t, t_index)
#      25         return model_mean
#      26     else:
# ---> 27         posterior_variance_t = extract(posterior_variance, t, x.shape)
#      28         noise = torch.randn_like(x)
#      29         return model_mean + torch.sqrt(posterior_variance_t) * noise
#
# <ipython-input-9-0702ca038597> in extract(a, t, x_shape)
#       4 def extract(a, t, x_shape):
#       5     batch_size = t.shape[0]
# ----> 6     out = a.gather(-1, t.cpu())
#       7     return out.reshape(batch_size, *((1,) * (len(x_shape) - 1))).to(t.device)
#       8
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
  batch = next(iter(dataloader))[0]
  noise=torch.randn_like(batch).to(device)
  sample_data = sample(
        student_model,
        noise,
        image_size=global_var["image_size"],
        timestep = 4,
        batch_size=global_var["batch_size"],
        channels=global_var["channels"]
      )
  show_batch(sample_data[-1].cpu().detach())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Show results

# %%
with torch.no_grad():
  batch = next(iter(dataloader))[0]
  noise=torch.randn_like(batch).to(device)
  sample_data = sample(
        student_model,
        noise,
        image_size=global_var["image_size"],
        timestep = 4,
        batch_size=global_var["batch_size"],
        channels=global_var["channels"]
      )
  show_batch(sample_data[-1].cpu().detach())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
with torch.no_grad():
  batch = next(iter(dataloader))[0]
  noise=torch.randn_like(batch).to(device)
  sample_data = sample(
        teacher_model,
        noise,
        image_size=global_var["image_size"],
        timestep = teacher_timesteps,
        batch_size=global_var["batch_size"],
        channels=global_var["channels"]
      )
  show_batch(sample_data[-1].cpu().detach())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #Save student model on github

# %%
#student_path = '/content/student_model_fer_1.pth'

#torch.save(student_model.state_dict(), student_path)

#!git config --global user.name "FedericoRaschiatore0123"
#!git config --global user.email "raschiatore.2071132@studenti.uniroma1.it"

#!git clone https://github.com/FedericoRaschiatore0123/Neural_Network.git

#!mv /content/student_model_fer_1.pth /content/Neural_Network/models

#%cd /content/Neural_Network

#!git add .
#!git commit -m "Added student model"

#!git remote rm origin
#!git remote add origin https://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@github.com/FedericoRaschiatore0123/Neural_Network.git
#!git push -u origin main

#%cd ..
# Out:
# /content/Neural_Network
# [main b0aef23] Added student model
#  1 file changed, 0 insertions(+), 0 deletions(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 28.60 MiB | 11.53 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/FedericoRaschiatore0123/Neural_Network.git
#    00a5cd7..b0aef23  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# /content

# %% [markdown]
# #Evaluate
#
# In this section I compared the quality of generated images using the Frechet Inception Distance (FID). The FID score is computed for both the models.
#
# **FID Calculation Function:**
#
# The compute_FID function takes a pretrained InceptionV3 model (wrapper_model), generated data, and reference data (real images).
# Both the generated and reference data are resized to (299, 299) and converted to 3-channel images for compatibility with InceptionV3.
# The Frechet Inception Distance is calculated using the metrics.FrechetInceptionDistance class, which compares the statistics of the generated and real data to compute the FID score.

# %%
def compute_FID(wrapper_model, generated_data, reference_data):

  resized_generated = tt.Resize((299, 299))(generated_data.cpu().repeat(1, 3, 1, 1))
  resized_reference = tt.Resize((299, 299))(reference_data.cpu().repeat(1, 3, 1, 1))

  fid_metrics = metrics.FrechetInceptionDistance(wrapper_model, 2048).to(device)

  fid_metrics.update(resized_generated.to(device), is_real=False)
  fid_metrics.update(resized_reference.to(device), is_real=True)
  fid_value = fid_metrics.compute()

  return fid_value

# %%
wrapper_model = models.inception_v3(pretrained=True)
wrapper_model.fc = torch.nn.Identity()
wrapper_model.eval()
wrapper_model.to(device)

reference = next(iter(dataloader))[0]

with torch.no_grad():
  batch = next(iter(dataloader))[0]
  noise=torch.randn_like(batch).to(device)
  student_data = sample(
        student_model,
        noise,
        image_size=global_var["image_size"],
        timestep = global_var["student_timesteps"],
        batch_size=global_var["batch_size"],
        channels=global_var["channels"]
      )

FID = compute_FID(wrapper_model, student_data[-1], reference)

show_batch(tt.Resize((299, 299))(student_data[-1].cpu().repeat(1, 3, 1, 1)))
show_batch(tt.Resize((299, 299))(reference.cpu().repeat(1, 3, 1, 1)))
print("The output FID value is: ", FID)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The output FID value is:  tensor(102.6405, device='cuda:0')

# %%
wrapper_model = models.inception_v3(pretrained=True)
wrapper_model.fc = torch.nn.Identity()
wrapper_model.eval()
wrapper_model.to(device)

reference = next(iter(dataloader))[0]

with torch.no_grad():
  batch = next(iter(dataloader))[0]
  noise=torch.randn_like(batch).to(device)
  teacher_data = sample(
        teacher_model,
        noise,
        image_size=global_var["image_size"],
        timestep = global_var["teacher_timesteps"],
        batch_size=global_var["batch_size"],
        channels=global_var["channels"]
      )

FID = compute_FID(wrapper_model, teacher_data[-1], reference)

show_batch(tt.Resize((299, 299))(teacher_data[-1].cpu().repeat(1, 3, 1, 1)))
show_batch(tt.Resize((299, 299))(reference.cpu().repeat(1, 3, 1, 1)))
print("The output FID value is: ", FID)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The output FID value is:  tensor(58.4841, device='cuda:0')
